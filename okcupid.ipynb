# %% [markdown]
# essay0- My self summary
# essay1- What I’m doing with my life
# essay2- I’m really good at
# essay3- The first thing people usually notice about me
# essay4- Favorite books, movies, show, music, and food
# essay5- The six things I could never do without
# essay6- I spend a lot of time thinking about
# essay7- On a typical Friday night I am
# essay8- The most private thing I am willing to admit
# essay9- You should message me if...

# %%
import pandas as pd
import seaborn as sns
import numpy as np 


df = pd.read_csv('okcupid_profiles.csv')
df
# Out:
#        age     status sex orientation       body_type               diet  \
# 0       22     single   m    straight  a little extra  strictly anything
# 1       35     single   m    straight         average       mostly other
# 2       38  available   m    straight            thin           anything
# 3       23     single   m    straight            thin         vegetarian
# 4       29     single   m    straight        athletic                NaN
# ...    ...        ...  ..         ...             ...                ...
# 59941   59     single   f    straight             NaN                NaN
# 59942   24     single   m    straight             fit    mostly anything
# 59943   42     single   m    straight         average    mostly anything
# 59944   27     single   m    straight        athletic    mostly anything
# 59945   39     single   m         gay         average                NaN
#
#            drinks      drugs                          education  \
# ...

# %%
df.columns
# Out:
# Index(['age', 'status', 'sex', 'orientation', 'body_type', 'diet', 'drinks',
#        'drugs', 'education', 'ethnicity', 'height', 'income', 'job',
#        'last_online', 'location', 'offspring', 'pets', 'religion', 'sign',
#        'smokes', 'speaks', 'essay0', 'essay1', 'essay2', 'essay3', 'essay4',
#        'essay5', 'essay6', 'essay7', 'essay8', 'essay9'],
#       dtype='object')

# %%
df.orientation.unique()
# Out:
# array(['straight', 'bisexual', 'gay'], dtype=object)

# %%
df.status.unique()
# Out:
# array(['single', 'available', 'seeing someone', 'married', 'unknown'],
#       dtype=object)

# %%
df.ethnicity.unique()
# Out:
# array(['asian, white', 'white', nan, 'asian, black, other',
#        'white, other', 'hispanic / latin, white', 'hispanic / latin',
#        'pacific islander, white', 'asian', 'black, white',
#        'pacific islander', 'asian, native american',
#        'asian, pacific islander', 'black, native american, white',
#        'middle eastern, other', 'native american, white', 'indian',
#        'black', 'black, native american, hispanic / latin, other',
#        'black, native american, hispanic / latin',
#        'asian, black, pacific islander',
#        'asian, middle eastern, black, native american, indian, pacific islander, hispanic / latin, white, other',
#        'other', 'hispanic / latin, other', 'asian, black',
#        'middle eastern, white', 'native american, white, other',
#        'black, native american', 'black, white, other',
#        'hispanic / latin, white, other', 'middle eastern', 'black, other',
# ...

# %%
df.body_type.unique()
# Out:
# array(['a little extra', 'average', 'thin', 'athletic', 'fit', nan,
#        'skinny', 'curvy', 'full figured', 'jacked', 'rather not say',
#        'used up', 'overweight'], dtype=object)

# %%
df.diet.unique()
# Out:
# array(['strictly anything', 'mostly other', 'anything', 'vegetarian', nan,
#        'mostly anything', 'mostly vegetarian', 'strictly vegan',
#        'strictly vegetarian', 'mostly vegan', 'strictly other',
#        'mostly halal', 'other', 'vegan', 'mostly kosher',
#        'strictly halal', 'halal', 'strictly kosher', 'kosher'],
#       dtype=object)

# %%
df.pets.unique()
# Out:
# array(['likes dogs and likes cats', 'has cats', 'likes cats', nan,
#        'has dogs and likes cats', 'likes dogs and has cats',
#        'likes dogs and dislikes cats', 'has dogs',
#        'has dogs and dislikes cats', 'likes dogs',
#        'has dogs and has cats', 'dislikes dogs and has cats',
#        'dislikes dogs and dislikes cats', 'dislikes cats',
#        'dislikes dogs and likes cats', 'dislikes dogs'], dtype=object)

# %%
df.religion.unique()
# Out:
# array(['agnosticism and very serious about it',
#        'agnosticism but not too serious about it', nan, 'atheism',
#        'christianity', 'christianity but not too serious about it',
#        'atheism and laughing about it',
#        'christianity and very serious about it', 'other', 'catholicism',
#        'catholicism but not too serious about it',
#        'catholicism and somewhat serious about it',
#        'agnosticism and somewhat serious about it',
#        'catholicism and laughing about it',
#        'agnosticism and laughing about it', 'agnosticism',
#        'atheism and somewhat serious about it',
#        'buddhism but not too serious about it',
#        'other but not too serious about it', 'buddhism',
#        'other and laughing about it',
#        'judaism but not too serious about it',
#        'buddhism and laughing about it',
#        'other and somewhat serious about it',
#        'other and very serious about it',
# ...

# %%
import matplotlib.pyplot as plt

# Sample data
categories = ['Category A', 'Category B', 'Category C']
values = [10, 20, 30]

# Creating the bar plot
plt.bar(categories, values)

# Adding title and labels
plt.title('Sample Bar Plot')
plt.xlabel('Categories')
plt.ylabel('Values')

# Displaying the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

value_counts = df['orientation'].value_counts()
colors = ['blue', 'pink', 'green']

plt.bar(value_counts.index, value_counts.values, color=colors)
ax = plt.gca()  
ax.set_facecolor('#bce2e6')
plt.grid(color='white', linestyle='-', linewidth=0.5)



plt.title('orientation')
plt.xlabel('Unique Values')
plt.ylabel('Counts')


plt.show()

# %%
value_counts = df['sex'].value_counts()
colors = ['blue', 'pink', 'green']

plt.bar(value_counts.index, value_counts.values, color=colors)
ax = plt.gca()  
ax.set_facecolor('#bce2e6')
plt.grid(color='white', linestyle='-', linewidth=0.5)



plt.title('sex')
plt.xlabel('Unique Values')
plt.ylabel('Counts')


plt.show()

# %%
value_counts = df['status'].value_counts()
colors = ['blue', 'pink', 'green']

plt.bar(value_counts.index, value_counts.values, color=colors)
ax = plt.gca()  
ax.set_facecolor('#bce2e6')
plt.grid(color='white', linestyle='-', linewidth=0.5)



plt.title('status')
plt.xlabel('Unique Values')
plt.ylabel('Counts')


plt.show()

# %%
value_counts = df['age'].value_counts()
colors = ['blue', 'pink', 'green','red','yellow']

plt.bar(value_counts.index, value_counts.values, color=colors)
ax = plt.gca()  
ax.set_facecolor('#bce2e6')
plt.grid(color='white', linestyle='-', linewidth=0.5)



plt.title('age')
plt.xlabel('Unique Values')
plt.ylabel('Counts')


plt.show()

# %%
value_counts = df['drugs'].value_counts()
colors = ['blue', 'pink', 'green','red','yellow']

plt.bar(value_counts.index, value_counts.values, color=colors)
ax = plt.gca()  
ax.set_facecolor('#bce2e6')
plt.grid(color='white', linestyle='-', linewidth=0.5)



plt.title('drugs')
plt.xlabel('Unique Values')
plt.ylabel('Counts')


plt.show()

# %%
value_counts = df['education'].value_counts()
colors = ['blue', 'pink', 'green','red','yellow']

plt.barh(value_counts.index, value_counts.values, color=colors)
ax = plt.gca()  
ax.set_facecolor('#bce2e6')
plt.grid(color='white', linestyle='-', linewidth=0.5)



plt.title('education')
plt.xlabel('Unique Values')
plt.ylabel('Counts')
#ax.invert_xaxis()

plt.show()

# %%
value_counts = df['height'].value_counts()
colors = ['blue', 'pink', 'green','red','yellow']

plt.bar(value_counts.index, value_counts.values, color=colors)
ax = plt.gca()  
ax.set_facecolor('#bce2e6')
plt.grid(color='white', linestyle='-', linewidth=0.5)



plt.title('height')
plt.xlabel('Unique Values')
plt.ylabel('Counts')
#ax.invert_xaxis()

plt.show()

# %%
df.last_online.unique()
# Out:
# array(['2012-06-28-20-30', '2012-06-29-21-41', '2012-06-27-09-10', ...,
#        '2012-06-02-08-16', '2012-02-17-20-44', '2012-06-14-16-51'],
#       dtype=object)

# %%
value_counts = df['offspring'].value_counts()
colors = ['blue', 'pink', 'green','red','yellow']

plt.barh(value_counts.index, value_counts.values, color=colors)
ax = plt.gca()  
ax.set_facecolor('#bce2e6')
plt.grid(color='white', linestyle='-', linewidth=0.5)



plt.title('offspring')
plt.xlabel('Unique Values')
plt.ylabel('Counts')
#ax.invert_xaxis()

plt.show()

# %%
value_counts = df['body_type'].value_counts()
colors = ['blue', 'pink', 'green','red','yellow']

plt.barh(value_counts.index, value_counts.values, color=colors)
ax = plt.gca()  
ax.set_facecolor('#bce2e6')
plt.grid(color='white', linestyle='-', linewidth=0.5)



plt.title('body_type')
plt.xlabel('Unique Values')
plt.ylabel('Counts')
#ax.invert_xaxis()

plt.show()

# %%
value_counts = df['pets'].value_counts()
colors = ['blue', 'pink', 'green','red','yellow']

plt.barh(value_counts.index, value_counts.values, color=colors)
ax = plt.gca()  
ax.set_facecolor('#bce2e6')
plt.grid(color='white', linestyle='-', linewidth=0.5)



plt.title('pets')
plt.xlabel('Unique Values')
plt.ylabel('Counts')
#ax.invert_xaxis()

plt.show()

# %%
value_counts = df['diet'].value_counts()
colors = ['blue', 'pink', 'green','red','yellow']

plt.barh(value_counts.index, value_counts.values, color=colors)
ax = plt.gca()  
ax.set_facecolor('#bce2e6')
plt.grid(color='white', linestyle='-', linewidth=0.5)



plt.title('diet')
plt.xlabel('Unique Values')
plt.ylabel('Counts')
#ax.invert_xaxis()

plt.show()

# %%
value_counts = df['job'].value_counts()
colors = ['blue', 'pink', 'green','red','yellow']

plt.barh(value_counts.index, value_counts.values, color=colors)
ax = plt.gca()  
ax.set_facecolor('#bce2e6')
plt.grid(color='white', linestyle='-', linewidth=0.5)



plt.title('job')
plt.xlabel('Unique Values')
plt.ylabel('Counts')
#ax.invert_xaxis()

plt.show()

# %%
value_counts = df['sign'].value_counts()
plt.figure(figsize=(5, 10))
colors = ['blue', 'pink', 'green','red','yellow']

plt.barh(value_counts.index, value_counts.values, color=colors)
ax = plt.gca()  
ax.set_facecolor('#bce2e6')
plt.grid(color='white', linestyle='-', linewidth=0.5)



plt.title('job')
plt.xlabel('Unique Values')
plt.ylabel('Counts')
#ax.invert_xaxis()

plt.show()

# %%
df
# Out:
#        age     status sex orientation       body_type               diet  \
# 0       22     single   m    straight  a little extra  strictly anything
# 1       35     single   m    straight         average       mostly other
# 2       38  available   m    straight            thin           anything
# 3       23     single   m    straight            thin         vegetarian
# 4       29     single   m    straight        athletic                NaN
# ...    ...        ...  ..         ...             ...                ...
# 59941   59     single   f    straight             NaN                NaN
# 59942   24     single   m    straight             fit    mostly anything
# 59943   42     single   m    straight         average    mostly anything
# 59944   27     single   m    straight        athletic    mostly anything
# 59945   39     single   m         gay         average                NaN
#
#            drinks      drugs                          education  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59946 entries, 0 to 59945
# Data columns (total 31 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          59946 non-null  int64
#  1   status       59946 non-null  object
#  2   sex          59946 non-null  object
#  3   orientation  59946 non-null  object
#  4   body_type    54650 non-null  object
#  5   diet         35551 non-null  object
#  6   drinks       56961 non-null  object
#  7   drugs        45866 non-null  object
#  8   education    53318 non-null  object
#  9   ethnicity    54266 non-null  object
#  10  height       59943 non-null  float64
#  11  income       59946 non-null  int64
#  12  job          51748 non-null  object
#  13  last_online  59946 non-null  object
#  14  location     59946 non-null  object
#  15  offspring    24385 non-null  object
#  16  pets         40025 non-null  object
#  17  religion     39720 non-null  object
# ...

# %%
#copy the data into a new DataFrame to keep the original

# %%
data = df.copy()

# %%
#inches to cm

# %%
data.height = data.height.apply(lambda x: round(x * 2.54, 0))

# %%
data.height
# Out:
# 0        190.0
# 1        178.0
# 2        173.0
# 3        180.0
# 4        168.0
#          ...
# 59941    157.0
# 59942    183.0
# 59943    180.0
# 59944    185.0
# 59945    173.0
# Name: height, Length: 59946, dtype: float64

# %%
data.describe()
# Out:
#                 age       height          income
# count  59946.000000  59943.00000    59946.000000
# mean      32.340290    173.45997    20033.222534
# std        9.452779     10.10919    97346.192104
# min       18.000000      3.00000       -1.000000
# 25%       26.000000    168.00000       -1.000000
# 50%       30.000000    173.00000       -1.000000
# 75%       37.000000    180.00000       -1.000000
# max      110.000000    241.00000  1000000.000000

# %%
#Missing values

# %%
mask = data.height.isna()
data.loc[mask,'height'] = data.height.median()

# %%
data.loc[df.income == -1, 'income'] = np.NaN

# %%
print(f'People that do not declare income: {data.income.isna().sum()/len(df):0.0%}')
# Out:
# People that do not declare income: 81%

# %%
isna_cols = data.loc[:,data.isna().any()].columns
missing_values = data[isna_cols[:12]].isna().sum().sort_values(ascending=False)

# %%
plt.style.use('ggplot')
fig0, ax0 = plt.subplots(figsize=(10,4))
sns.barplot(x=missing_values.index,y=missing_values,palette='pastel')
ax0.set(xticks=range(len(missing_values)),title='Missing values per feature (excluding essays)', ylabel = 'count')
ax0.set_xticklabels(labels=missing_values.index, rotation=70,fontsize=13)
ax0.annotate('81% of users do not declare income', xy = (0.4, 48000), 
             xytext=(2,41000),fontsize=14,
            arrowprops=dict(facecolor='black', shrink=0.05));
fig0.tight_layout()
fig0.savefig('figure_00.png')

# %%
#Sex Distribution & Orientation

# %%
fig1, ax1 = plt.subplots(ncols=2,figsize=(14, 5))

cat_cols = ['sex', 'orientation']
titles = ['Sex distribution', 'Sexual orientation']

sns.countplot(data=data, x='sex', ax=ax1[0], width=0.4,palette='pastel')
sns.countplot(data=data, x='orientation', hue='sex', ax=ax1[1], palette='pastel')
fig1.savefig('figure_01.png');

# %%
#Numerical Features: Age, Height

# %%
sns.set_style("white")
num_cols = ['age','height']
xlims = [(15, 70), (130,220)]
titles = ['Age Distribution', 'Height Distribution']
fig2, ax2 = plt.subplots(ncols=2, figsize=(14,5),sharey=False)
for i, col in enumerate(num_cols):
    sns.histplot(data=data, x=col, ax=ax2[i], hue='sex', element='step',bins=40, alpha=0.4,palette='pastel')
    ax2[i].set(xlim=xlims[i], title = titles[i])
fig2.savefig('figure_02.png')

# %%
#we dont care about the location maybeee??

# %%
#Marring categories

# %%
def map_cat(a_string, a_dic):
    ''' a_string: a string we want to map with a_dic
        a_dic: a dictionary whose keys are tuples'''
    for k in a_dic:
        if a_string in k:
            return a_dic.get(k)
    return np.NaN

# %%
data.body_type.value_counts(dropna=False)
# Out:
# average           14652
# fit               12711
# athletic          11819
# NaN                5296
# thin               4711
# curvy              3924
# a little extra     2629
# skinny             1777
# full figured       1009
# overweight          444
# jacked              421
# used up             355
# rather not say      198
# Name: body_type, dtype: int64

# %%
#group body types
from pandas.api.types import CategoricalDtype

# %%
body_types_dic={('skinny','used up','thin'):'thin',
               ('average','fit','athletic','jacked'):'average',
               ('a little extra','curvy','full figured'):'curvy'}

body_categories = CategoricalDtype(categories=['thin','average','curvy'], ordered=True)

data['body_type_'] = data.body_type.apply(map_cat,args=(body_types_dic,)).astype(body_categories)
data.body_type_ = data.body_type_.fillna(body_categories.categories[int(np.median(data.body_type_.cat.codes))])

# %%
data.body_type_
# Out:
# 0          curvy
# 1        average
# 2           thin
# 3           thin
# 4        average
#           ...
# 59941    average
# 59942    average
# 59943    average
# 59944    average
# 59945    average
# Name: body_type_, Length: 59946, dtype: category
# Categories (3, object): ['thin' < 'average' < 'curvy']

# %%
#education

# %%
education_categories = CategoricalDtype(categories=['High school','Undergraduate',
                                        'Graduate','Post-Graduate'],
                                        ordered=True)

# %%
education_dic= {('graduated from high school','dropped out of high school', 
                 'working on high school','high school'): 'High school',
                
                ('working on two-year college','dropped out of space camp',
                'two-year college', 'graduated from two-year college',
                'dropped out of college/university','dropped out of two-year college', 
                 'dropped out of med school', 'dropped out of law school'): 'Undergraduate',
                
                ('working on college/university', 'working on space camp',
                'graduated from masters program','graduated from college/university',
                'working on masters program','graduated from space camp',
                'college/university','graduated from law school', 
                 'working on ph.d program','space camp', 
                 'graduated from med school','working on med school',
                'masters program', 'dropped out of ph.d program',
                'law school','dropped out of masters program',
                'working on law school', 'med school') : 'Graduate', 
                
                ('graduated from ph.d program','ph.d program'): 'Post-Graduate'}

# %%
data['education_'] = data.education.apply(map_cat,args=(education_dic,)).astype(education_categories)

# %%
data['education_']
# Out:
# 0        Graduate
# 1        Graduate
# 2        Graduate
# 3        Graduate
# 4        Graduate
#            ...
# 59941    Graduate
# 59942    Graduate
# 59943    Graduate
# 59944    Graduate
# 59945    Graduate
# Name: education_, Length: 59946, dtype: category
# Categories (4, object): ['High school' < 'Undergraduate' < 'Graduate' < 'Post-Graduate']

# %%
#assign median values to the missing values

# %%
data.education_ = data.education_.fillna(education_categories.\
                                    categories[int(np.median(data['education_'].cat.codes))]).\
                                    astype(education_categories)

# %%
sns.set_style("darkgrid")
cat_cols = ['body_type_','education_']
titles = ['Body Type', 'Education']
fig4, ax4 = plt.subplots(ncols=2, figsize=(14,5),sharey=True)
for i, col in enumerate(cat_cols):
    sns.countplot(data=data, x=col, ax=ax4[i], hue='sex',palette='pastel')
    ax4[i].set(title = titles[i])
fig4.savefig('figure_04.png')

# %%
#Drinks & Drugs & Smokes

# %%
drinks_categories = CategoricalDtype(categories=['not at all','rarely','socially',
                                                 'often','very often','desperately'],
                                     ordered=True)
data['drinks_'] = data.drinks.astype(drinks_categories)
data.drinks_ = data.drinks_.fillna(drinks_categories.categories[int(np.median(data.drinks_.cat.codes))])

# %%
df.drugs.value_counts(dropna=False)
# Out:
# never        37724
# NaN          14080
# sometimes     7732
# often          410
# Name: drugs, dtype: int64

# %%
data['drugs_'] = data.drugs.fillna('never')
data.drugs_.value_counts(dropna=False)
data.drugs_ = pd.Categorical(data.drugs_, categories=['never', 'sometimes','often'], ordered=True)

# %%
data.smokes.value_counts(dropna=False)
# Out:
# no                43896
# NaN                5512
# sometimes          3787
# when drinking      3040
# yes                2231
# trying to quit     1480
# Name: smokes, dtype: int64

# %%
smokes_dic = {('no',):'no',
             ('sometimes', 'when drinking', 'trying to quit'):'sometimes',
              ('yes',):'yes'}
smokes_categories = CategoricalDtype(categories=['no', 'sometimes', 'yes'],ordered=True)
data['smokes_'] = data.smokes.apply(map_cat, args=(smokes_dic,)).astype(smokes_categories)
data.smokes_ = data.smokes_.fillna('no').astype(smokes_categories)
data.smokes_.value_counts(dropna=False).sort_index()
# Out:
# no           49408
# sometimes     8307
# yes           2231
# Name: smokes_, dtype: int64

# %%
sns.set_style("darkgrid")
cat_cols = ['drinks_', 'drugs_', 'smokes_']
titles = ['Drinks', 'Drugs', 'Smokes']
xlabels = [ list(drinks_categories.categories), ['never', 'sometimes','often'], list(smokes_categories.categories) ]
ticks = [6, 3, 3]
fig5, ax5 = plt.subplots(ncols=3, figsize=(14,6),sharey=True)
for i, col in enumerate(cat_cols):
    sns.countplot(data=data, x=col, ax=ax5[i], hue='sex',palette='pastel')
    ax5[i].set(title = titles[i], xticks = range(len(xlabels[i])) ,xlabel='', ylabel='')
    ax5[i].set_xticklabels(labels = xlabels[i], rotation=60,fontsize=12) 
fig5.tight_layout()
fig5.savefig('figure_05.png')

# %%
#pets

# %%
data.pets.value_counts(dropna=False)
# Out:
# NaN                                19921
# likes dogs and likes cats          14814
# likes dogs                          7224
# likes dogs and has cats             4313
# has dogs                            4134
# has dogs and likes cats             2333
# likes dogs and dislikes cats        2029
# has dogs and has cats               1474
# has cats                            1406
# likes cats                          1063
# has dogs and dislikes cats           552
# dislikes dogs and likes cats         240
# dislikes dogs and dislikes cats      196
# dislikes cats                        122
# dislikes dogs and has cats            81
# dislikes dogs                         44
# Name: pets, dtype: int64

# %%
data.pets = data.pets.fillna('No')

# %%
data.pets.value_counts(dropna=False)
# Out:
# No                                 19921
# likes dogs and likes cats          14814
# likes dogs                          7224
# likes dogs and has cats             4313
# has dogs                            4134
# has dogs and likes cats             2333
# likes dogs and dislikes cats        2029
# has dogs and has cats               1474
# has cats                            1406
# likes cats                          1063
# has dogs and dislikes cats           552
# dislikes dogs and likes cats         240
# dislikes dogs and dislikes cats      196
# dislikes cats                        122
# dislikes dogs and has cats            81
# dislikes dogs                         44
# Name: pets, dtype: int64

# %%
import re 
def likes_pet(s, species):
    dogs_regex = re.compile(r'((?<!dis)likes |has )dogs')
    cats_regex = re.compile(r'((?<!dis)likes |has )cats')
    if species == 'dog':
        return 'Yes' if bool(dogs_regex.search(s)) else 'No'
    elif species == 'cat':
        return 'Yes' if bool(cats_regex.search(s)) else 'No'
    else:
        return 'No'

# %%
data['likes_dogs_'] = data.pets.apply(likes_pet,args = ('dog',))
data['likes_cats_'] = data.pets.apply(likes_pet,args = ('cat',))
data['likes_dogs_'] = pd.Categorical(data.likes_dogs_,categories=['No', 'Yes'],ordered=True)
data['likes_cats_'] = pd.Categorical(data.likes_cats_,categories=['No', 'Yes'],ordered=True)

# %%
sns.set_style("darkgrid")
cat_cols = ['likes_dogs_', 'likes_cats_']
titles=['Likes Dogs', 'Likes Cats']
fig6, ax6 = plt.subplots(ncols=2, figsize=(14,5),sharey=True)
for i, col in enumerate(cat_cols):
    sns.countplot(data=data, x=col, ax=ax6[i], hue='sex', width=0.5, palette='pastel')
    ax6[i].set(title = titles[i],xlabel='', ylabel='')
fig6.savefig('figure_06.png')

# %%
#clustering users - unsupervised learning
#k-means clustering with scikit-lear

# %%
features = ['age', 'height', 'body_type_', 'education_', 'drinks_', 'drugs_', 'smokes_', 'likes_dogs_', 'likes_cats_']

# %%
X = data[features[0:2]].copy()
X.head()
# Out:
#    age  height
# 0   22   190.0
# 1   35   178.0
# 2   38   173.0
# 3   23   180.0
# 4   29   168.0

# %%
#numerical data

# %%
for feat in features[2:]:
    X[feat] = data[feat].cat.codes

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.set_output(transform='pandas')

X_scaled = scaler.fit_transform(X)

# %%
#Inertia

# %%
num_clusters=list(np.arange(1, 21))

inertias = []

for k in num_clusters:
  model = KMeans(n_clusters = k, n_init='auto')
  model.fit(X_scaled)
  inertias.append(model.inertia_)

# %%
fig7, ax7 = plt.subplots(figsize=(7, 5))

ax7.plot(num_clusters, inertias, '-o')
ax7.set(xticks=num_clusters, xlabel='clusters', title='Inertia')
fig7.savefig('figure_07.png')

# %%
k = 12
model = KMeans(n_clusters = k, n_init='auto')
model.fit(X_scaled)
data['membership'] = model.labels_
data.membership.value_counts()

fig8, ax8 = plt.subplots(figsize=(7, 5))

sns.countplot(data=data, x='membership', ax=ax8, hue='sex',palette='pastel')
ax8.set(title = 'Users per cluster', ylabel='');
fig8.savefig('figure_08.png')

# %%
#data[data['membership'=='1']] #find the features in every cluster 
data[data['membership'] == 5]
# Out:
#        age     status sex orientation       body_type                 diet  \
# 128     26     single   m    straight         average                  NaN
# 130     30  available   m    straight             NaN                  NaN
# 153     24  available   m    bisexual          skinny                  NaN
# 177     29     single   m    straight  a little extra         mostly halal
# 179     25     single   m    straight  a little extra      mostly anything
# ...    ...        ...  ..         ...             ...                  ...
# 59747   25     single   f    straight            thin             anything
# 59751   23     single   f    straight         average           vegetarian
# 59845   21     single   f    straight           curvy                  NaN
# 59895   23     single   f    straight             NaN  strictly vegetarian
# 59923   22     single   m    straight      overweight    strictly anything
#
#          drinks      drugs                          education  \
# ...

# %%
#get the features of every cluster

# %%
#match recommender

# %%
features = ['age', 'height', 'sex', 'orientation', 'body_type_', 
 'education_', 'drinks_', 'drugs_', 'smokes_', 'likes_dogs_', 'likes_cats_', 
 'membership']

# %%
data.loc[43:43,features] #checking user 43
# Out:
#     age  height sex orientation body_type_ education_   drinks_ drugs_  \
# 43   40   180.0   m    straight    average   Graduate  socially  never
#
#    smokes_ likes_dogs_ likes_cats_  membership
# 43      no         Yes          No           7

# %%
#find number of matchs from the same cluster for the user 42

# %%
##we need the user to input their personal details in order to find a match

# %%
users = data.loc[(data.sex == 'f') & 
               (data.membership == data.at[43, 'membership']) & 
               (data.orientation == 'straight')].index
print(f'And so we have found {len(users)} female users in the same cluster.\n ')
# Out:
# And so we have found 587 female users in the same cluster.

# %%
#data.loc[5:8,features]

# %%
#Distances

#Now we can prepare an ordered list based on affinitty. 
#First of all we need to calculate the distance between user 42 and the rest of profiles we have just found.

# %%
def distance(row, user):
    result = 0
    for i, v in enumerate(row):
        result += (v - user[i])**2
    return result ** 0.5;

# %%
user = X_scaled.loc[43]
distances = X_scaled.loc[users].apply(distance, axis = 1, args=(user,) ).sort_values();

# %%
data.loc[43:43, features]
# Out:
#     age  height sex orientation body_type_ education_   drinks_ drugs_  \
# 43   40   180.0   m    straight    average   Graduate  socially  never
#
#    smokes_ likes_dogs_ likes_cats_  membership
# 43      no         Yes          No           7

# %%
data.loc[distances.index, features].head(20)
# Out:
#        age  height sex orientation body_type_ education_   drinks_ drugs_  \
# 2597    40   180.0   f    straight    average   Graduate  socially  never
# 21342   39   180.0   f    straight    average   Graduate  socially  never
# 25202   41   180.0   f    straight    average   Graduate  socially  never
# 30504   41   180.0   f    straight    average   Graduate  socially  never
# 305     42   180.0   f    straight    average   Graduate  socially  never
# 57697   38   180.0   f    straight    average   Graduate  socially  never
# 29645   42   180.0   f    straight    average   Graduate  socially  never
# 15411   39   178.0   f    straight    average   Graduate  socially  never
# 40053   39   178.0   f    straight    average   Graduate  socially  never
# 1688    39   178.0   f    straight    average   Graduate  socially  never
# 53889   41   178.0   f    straight    average   Graduate  socially  never
# 47697   38   178.0   f    straight    average   Graduate  socially  never
# ...

# %%
#Affinity

# %% [markdown]
# S = np.exp(-D * gamma), where D is the distance between the two data points, and gamma is 1 / num_features.

# %%
gamma = 1 /(len(features))

# %%
S = pd.DataFrame(distances.apply(lambda x: round(np.exp(-x * gamma)*100,1)).rename('affinity'))
S.rename_axis('user_id', inplace=True)
print('Top ten users by affinity with user_id = 43')
S.head(10)
# Out:
# Top ten users by affinity with user_id = 43
#          affinity
# user_id
# 2597        100.0
# 21342        99.1
# 25202        99.1
# 30504        99.1
# 305          98.3
# 57697        98.3
# 29645        98.3
# 15411        98.1
# 40053        98.1
# 1688         98.1

# %%
#locate the #1 match for user 42

# %%
data.loc[31343:31343, features]
# Out:
#        age  height sex orientation body_type_ education_ drinks_     drugs_  \
# 31343   25   183.0   f    straight    average   Graduate   often  sometimes
#
#       smokes_ likes_dogs_ likes_cats_  membership
# 31343      no          No          No          10

# %%
#trying with a random sample user and failing so far

# %%
import random


random_index = random.randint(0, len(X_scaled) - 1)
user = X_scaled.iloc[random_index]
user_in_data = data.loc[random_index:random_index, features]
user_in_data
# Out:
#        age  height sex orientation body_type_ education_   drinks_ drugs_  \
# 27727   30   152.0   f    straight    average   Graduate  socially  never
#
#       smokes_ likes_dogs_ likes_cats_  membership
# 27727      no         Yes          No           6

# %% [markdown]
# ## making an if statement for a random user

# %%
#everything works here! 

#do it as a while loop and add the age at the front

# %%
index = user_in_data.index[0]

if data.loc[index, 'sex'] == 'm' and data.loc[index, 'orientation'] == 'straight':
    users = data.loc[(data['sex'] == 'f') & 
                     (data['membership'] == data.at[index, 'membership']) & 
                     (data['orientation'] == 'straight')].index
    print(f'And so we have found {len(users)} female users in the same cluster.\n')

elif data.loc[index, 'sex'] == 'f' and data.loc[index, 'orientation'] == 'straight':
    users = data.loc[(data['sex'] == 'm') & 
                     (data['membership'] == data.at[index, 'membership']) & 
                     (data['orientation'] == 'straight')].index
    print(f'And so we have found {len(users)} male users in the same cluster.\n')

elif data.loc[index, 'orientation'] == 'bisexual':
    users = data.loc[data['membership'] == data.at[index, 'membership']].index
    print(f'And so we have found {len(users)} bisexual users in the same cluster.\n')

elif data.loc[index, 'sex'] == 'm' and data.loc[index, 'orientation'] == 'gay':
    users = data.loc[(data['sex'] == 'm') & 
                     (data['membership'] == data.at[index, 'membership']) & 
                     (data['orientation'] == 'gay')].index
    print(f'And so we have found {len(users)} gay male users in the same cluster.\n')

else:
    users = data.loc[(data['sex'] == 'f') & 
                     (data['membership'] == data.at[index, 'membership']) & 
                     (data['orientation'] == 'gay')].index
    print(f'And so we have found {len(users)} lesbian female users in the same cluster.\n')
# Out:
# And so we have found 740 male users in the same cluster.

# %%
#lets try and find the matches of our random user

# %%
def distance(row, user):
    result = 0
    for i, v in enumerate(row):
        result += (v - user[i])**2
    return result ** 0.5;

# %%
#we are not getting the closest to distance matches 
distances = X_scaled.loc[users].apply(distance, axis = 1, args=(user,) ).sort_values();

# %%
data.loc[distances.index, features].head(20)
# Out:
#        age  height sex orientation body_type_ education_   drinks_ drugs_  \
# 31757   30   157.0   m    straight    average   Graduate  socially  never
# 48181   31   157.0   m    straight    average   Graduate  socially  never
# 30244   27   157.0   m    straight    average   Graduate  socially  never
# 40193   25   157.0   m    straight    average   Graduate  socially  never
# 3841    35   157.0   m    straight    average   Graduate  socially  never
# 41683   30   160.0   m    straight    average   Graduate  socially  never
# 14139   28   160.0   m    straight    average   Graduate  socially  never
# 2857    22   152.0   m    straight    average   Graduate  socially  never
# 21739   25   160.0   m    straight    average   Graduate  socially  never
# 20534   36   160.0   m    straight    average   Graduate  socially  never
# 45153   20   152.0   m    straight    average   Graduate  socially  never
# 30359   23   160.0   m    straight    average   Graduate  socially  never
# ...

# %%
#Affinity

# %%
gamma = 1 /(len(features))

# %%
S = pd.DataFrame(distances.apply(lambda x: round(np.exp(-x * gamma)*100,1)).rename('affinity'))
S.rename_axis('user_id', inplace=True)
print(f'Top ten users by affinity with user_id are')
S.head(10)
# Out:
# Top ten users by affinity with user_id are
#          affinity
# user_id
# 31757        96.0
# 48181        95.9
# 30244        95.2
# 40193        94.1
# 3841         94.1
# 41683        93.6
# 14139        93.4
# 2857         93.2
# 21739        92.4
# 20534        91.9

# %%
data.loc[index, features] #try to locate the top match from the random user
# Out:
# age                  30
# height            152.0
# sex                   f
# orientation    straight
# body_type_      average
# education_     Graduate
# drinks_        socially
# drugs_            never
# smokes_              no
# likes_dogs_         Yes
# likes_cats_          No
# membership            6
# Name: 27727, dtype: object

# %%
data.to_csv('clean_ok_cupid.csv')

# %% [markdown]
# # Work on the essays

# %%
essays = data[['essay0', 'essay1', 'essay2',
               'essay3', 'essay4', 'essay5', 'essay6', 
               'essay7', 'essay8', 'essay9']]

# %%
essays.head()
# Out:
#                                               essay0  \
# 0  about me:  i would love to think that i was so...
# 1  i am a chef: this is what that means. 1. i am ...
# 2  i'm not ashamed of much, but writing public te...
# 3          i work in a library and go to school. . .
# 4  hey how's it going? currently vague on the pro...
#
#                                               essay1  \
# 0  currently working as an international agent fo...
# 1  dedicating everyday to being an unbelievable b...
# 2  i make nerdy software for musicians, artists, ...
# 3          reading things written by old dead people
# 4                         work work work work + play
#
#                                               essay2  \
# 0  making people laugh. ranting about a good salt...
# 1  being silly. having ridiculous amonts of fun w...
# 2  improvising in different contexts. alternating...
# 3  playing synthesizers and organizing books acco...
# ...

# %%
essays.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59946 entries, 0 to 59945
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   essay0  54458 non-null  object
#  1   essay1  52374 non-null  object
#  2   essay2  50308 non-null  object
#  3   essay3  48470 non-null  object
#  4   essay4  49409 non-null  object
#  5   essay5  49096 non-null  object
#  6   essay6  46175 non-null  object
#  7   essay7  47495 non-null  object
#  8   essay8  40721 non-null  object
#  9   essay9  47343 non-null  object
# dtypes: object(10)
# memory usage: 4.6+ MB

# %%
essays = essays.fillna('.') #fill empty entries with '.'
essays.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59946 entries, 0 to 59945
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   essay0  59946 non-null  object
#  1   essay1  59946 non-null  object
#  2   essay2  59946 non-null  object
#  3   essay3  59946 non-null  object
#  4   essay4  59946 non-null  object
#  5   essay5  59946 non-null  object
#  6   essay6  59946 non-null  object
#  7   essay7  59946 non-null  object
#  8   essay8  59946 non-null  object
#  9   essay9  59946 non-null  object
# dtypes: object(10)
# memory usage: 4.6+ MB

# %%
essays.essay9[100]
# Out:
# "you're a hip girl that likes to explore new places and share familiar ones. you genuinely like people and are optimistic about the fate of the world. you believe in evolution and that humans are innately good creatures, despite what that doucebag just said. you are an independent thinker and a savvy traveler. you like a guy who has confidence, decent looks, and a questioning (not questionable) personality."

# %% [markdown]
# As the original dataset consists of 59946 rows of data, it will be problematic to process all at once. To simplify the process, we select a number of random samples without replacement (3000, approximately 5% of the data). No random state is assigned to see the impact sample variations will have on model coherence.

# %%
#aggregating user-generated essays
texts = []
for i in range(59946):
    texts.append(''.join(essays.loc[i]))
essays['texts'] = texts
sample = essays['texts'].sample(n=3000, replace=False)
sample = sample.reset_index()
sample['texts'][0:10]
# Out:
# 0    .i'm finally getting to enjoy that work-life b...
# 1    try moving to a new country with your piano in...
# 2                                           ..........
# 3    .looking forward building my business co-paren...
# 4    hi. i enjoy mostly reading, looking at stars, ...
# 5    are you into yoga, museums, travel, backpackin...
# 6    im very outgoing down to earth i love to work ...
# 7                                           ..........
# 8    born and raised in new york, spent some qualit...
# 9    ..dancing !!.hip-hop, punjabi music indian, th...
# Name: texts, dtype: object

# %%
import spacy
from spacy.lang.en.examples import sentences
import en_core_web_sm
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[126], line 3
#       1 import spacy
#       2 from spacy.lang.en.examples import sentences
# ----> 3 import en_core_web_sm
#
# ModuleNotFoundError: No module named 'en_core_web_sm'

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer, PorterStemmer
nltk.download('omw-1.4')
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
# Out:
# [nltk_data] Downloading package omw-1.4 to /home/yv/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
import gensim
from gensim import corpora
from gensim.parsing.preprocessing import remove_stopwords, strip_punctuation, preprocess_string, stem_text
from gensim.models import LdaMulticore, Word2Vec
from gensim.models.coherencemodel import CoherenceModel

from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.manifold import TSNE

# %%
import string

# %%
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /home/yv/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/yv/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/yv/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[125], line 1
# ----> 1 import en_core_web_sm
#
# ModuleNotFoundError: No module named 'en_core_web_sm'

# %%
#text preprocessing
nlp = spacy.load('en_core_web_sm')
all_stopwords = nlp.Defaults.stop_words
all_stopwords.add("i")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[124], line 2
#       1 #text preprocessing
# ----> 2 nlp = spacy.load('en_core_web_sm')
#       3 all_stopwords = nlp.Defaults.stop_words
#       4 all_stopwords.add("i")
#
# File ~/anaconda3/lib/python3.11/site-packages/spacy/__init__.py:51, in load(name, vocab, disable, enable, exclude, config)
#      27 def load(
#      28     name: Union[str, Path],
#      29     *,
#    (...)
#      34     config: Union[Dict[str, Any], Config] = util.SimpleFrozenDict(),
#      35 ) -> Language:
#      36     """Load a spaCy model from an installed package or a local path.
#      37
#      38     name (str): Package name or model path.
#    (...)
#      49     RETURNS (Language): The loaded nlp object.
#      50     """
# ---> 51     return util.load_model(
#      52         name,
#      53         vocab=vocab,
# ...

# %%
sample['texts']
sample['texts'] = sample['texts'].apply(lambda x: remove_stopwords(x))
sample_tokens = sample['texts'].apply(lambda x: word_tokenize(x))

sample_clean = sample_tokens.apply(lambda text: " ".join(i for i in text if i not in all_stopwords))
sample_np = sample_clean.apply(lambda x: x.translate(str.maketrans(' ', ' ', string.punctuation)))
sample_np = sample_np.apply(lambda x: x.lower().strip())
sample_np = sample_np.apply(lambda x: remove_stopwords(x)) #second pass for certainty
